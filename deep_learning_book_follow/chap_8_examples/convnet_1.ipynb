# %% [markdown]
# # MNIST Convolutional Neural Network Test
#
# ### Imports

# %%
import tensorflow as tf
from tensorflow import keras
from keras import layers
import numpy as np
import matplotlib.pyplot as plt
# Out:
# c:\users\danie\pycharmprojects\tensorflowtest\venv\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# c:\users\danie\pycharmprojects\tensorflowtest\venv\lib\site-packages\numpy\.libs\libopenblas.GK7GX5KEQ4F6UYO3P26ULGBQYHGQO7J4.gfortran-win_amd64.dll
# c:\users\danie\pycharmprojects\tensorflowtest\venv\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
# image is 28 x 28 x 1
inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(filters = 32, kernel_size=3, activation="relu")(inputs)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters = 64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(10, activation="softmax")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
# gathering data
from tensorflow.keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images, test_images = train_images / 255.0, test_images / 255.0
# Out:
# <tf.Tensor: shape=(1, 10), dtype=float32, numpy=
# array([[0.09751023, 0.10062103, 0.10272475, 0.09511932, 0.10557827,
#         0.09405448, 0.09960976, 0.09982253, 0.10858909, 0.09637051]],
#       dtype=float32)>

# %%
model.compile(optimizer="rmsprop", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
model.fit(train_images, train_labels, batch_size=64, epochs=5)
# Out:
# Epoch 1/5
#  - ETA: 8s - loss: 0.2425 - accuracy: 0.9245
# Epoch 2/5
# 938/938 [==============================] - 17s 18ms/step - loss: 0.0435 - accuracy: 0.9869
# Epoch 3/5
# 938/938 [==============================] - 17s 19ms/step - loss: 0.0306 - accuracy: 0.9908
# Epoch 4/5
#  - ETA: 9s - loss: 0.0212 - accuracy: 0.9930
# Epoch 5/5
#  - ETA: 1s - loss: 0.0179 - accuracy: 0.9947

# %%
model.evaluate(test_images, test_labels)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0296 - accuracy: 0.9918
# [0.02957431599497795, 0.9918000102043152]
