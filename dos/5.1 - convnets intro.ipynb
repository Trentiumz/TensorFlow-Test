# %% [markdown]
# ### Imports

# %%
import tensorflow as tf
from tensorflow import keras
from keras import models, layers
from keras.datasets import mnist
import tensorflow_datasets as tfds
from tensorflow.keras.layers import Conv2D, Dense, MaxPooling2D, Flatten
import numpy as np
import matplotlib.pyplot as plt
import random

# %% [markdown]
# ###Data

# %%
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

train_images = train_images.astype("float32") / 255
test_images = test_images.astype("float32") / 255

train_images = train_images.reshape((train_images.shape[0], 28, 28, 1))
test_images = test_images.reshape((test_images.shape[0], 28, 28, 1))

# %% [markdown]
# ### Network

# %%
model = models.Sequential([
    Conv2D(32, (3, 3), activation="relu", input_shape=(28, 28, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation="relu"),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation="relu"),
    Flatten(),
    Dense(64, activation="relu"),
    Dense(10, activation="softmax")])

model.compile(optimizer="rmsprop", loss=tf.losses.SparseCategoricalCrossentropy(), metrics=["accuracy"])

# %%
model.fit(train_images, train_labels, epochs=5, batch_size=64, validation_split=0.2)
# Out:
# Epoch 1/5
#  - ETA: 2s - loss: 0.5060 - accuracy: 0.8404
# Epoch 2/5
#  - ETA: 14s - loss: 0.0584 - accuracy: 0.9826
# Epoch 3/5
# 750/750 [==============================] - 16s 22ms/step - loss: 0.0340 - accuracy: 0.9891 - val_loss: 0.0477 - val_accuracy: 0.9861
# Epoch 4/5
#  - ETA: 1s - loss: 0.0240 - accuracy: 0.9921
# Epoch 5/5
# 750/750 [==============================] - 17s 22ms/step - loss: 0.0205 - accuracy: 0.9932 - val_loss: 0.0487 - val_accuracy: 0.9875

# %% [markdown]
# #### Evaluation

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print("Loss:", test_loss)
print("Accuracy:", test_acc)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0369 - accuracy: 0.9889
# Loss: 0.036916449666023254
# Accuracy: 0.9889000058174133

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# module_wrapper_40 (ModuleWra (None, 26, 26, 32)        320
# _________________________________________________________________
# module_wrapper_41 (ModuleWra (None, 13, 13, 32)        0
# _________________________________________________________________
# module_wrapper_42 (ModuleWra (None, 11, 11, 64)        18496
# _________________________________________________________________
# module_wrapper_43 (ModuleWra (None, 5, 5, 64)          0
# _________________________________________________________________
# module_wrapper_44 (ModuleWra (None, 3, 3, 64)          36928
# _________________________________________________________________
# module_wrapper_45 (ModuleWra (None, 576)               0
# _________________________________________________________________
# module_wrapper_46 (ModuleWra (None, 64)                36928
# _________________________________________________________________
# module_wrapper_47 (ModuleWra (None, 10)                650
# =================================================================
# Total params: 93,322
# Trainable params: 93,322
# Non-trainable params: 0
# _________________________________________________________________
